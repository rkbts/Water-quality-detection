# %%
import glob
import cv2
import scipy
import statistics
from scipy.stats import skew
import numpy as np
import os
from tabulate import tabulate

#images = os.listdir('http://localhost:8888/tree/Desktop/Water_sample_images/Black_water')
#num_images = len(images)

files="Clean_water"
path=glob.glob(files+'/*.png')

data = [] # using an array is more convenient for tabulate.
j=1

for i in path:
    img = cv2.imread(i)
    #cv2.imshow(img,1)
    cv2.waitKey(0)
    cv2.destroyAllWindows()
    avgR = np.mean(img[:,:,2])/100
    avgG = np.mean(img[:,:,1])/100
    avgB = np.mean(img[:,:,0])/100

    varR = np.std(img[:,:,2])/100
    varG = np.std(img[:,:,1])/100
    varB = np.std(img[:,:,0])/100

    skewR = np.mean(scipy.stats.skew(img[:,:,2]))/100
    skewG = np.mean(scipy.stats.skew(img[:,:,1]))/100
    skewB = np.mean(scipy.stats.skew(img[:,:,0]))/100
    
    data.append([j,i, avgR, avgG, avgB, varR, varG, varB, skewR, skewG, skewB])
    j+=1
for i in range(len(data)):
    print(data[i])
    
#print(tabulate(data, headers=['img_name','R', 'G', 'B','varR','varG','varB','skewR','skewG','skewB'], tablefmt='fancy_grid'))
# Out:
# [1, 'Clean_water\\1 (2).png', 0.01854, 1.2714453333333333, 1.3673244444444443, 0.025501493638172997, 0.15166073215642284, 0.11014175342218582, 0.017569547552814205, -0.002569017498762207, -0.00019314492652717743]
# [2, 'Clean_water\\1 (3).png', 0.008769777777777777, 0.797852, 1.2788666666666666, 0.011595683965048544, 0.06328738233381649, 0.05856487381053974, 0.015200753687620501, -0.0010235742895284726, -0.008367458869014223]
# [3, 'Clean_water\\1 (4).png', 0.3818195555555555, 1.7832715555555554, 1.9392195555555554, 0.6184330128961442, 0.4045465983759847, 0.21396652857611534, 0.013417422863395248, -0.016622211453691253, -0.017295471028117446]
# [4, 'Clean_water\\1 (5).png', 1.144129777777778, 1.6544159999999999, 1.908403111111111, 0.6948446496575537, 0.5679597257333578, 0.501349296012813, -0.0007862080145380711, -0.004236300589973484, -0.007323995359262898]
# ...

# %%
import glob
import cv2
import scipy
import statistics
from scipy.stats import skew
import numpy as np
import os
from tabulate import tabulate

#images = os.listdir('http://localhost:8888/tree/Desktop/Water_sample_images/Black_water')
#num_images = len(images)

files="Clean_water"
path=glob.glob(files+'/*.jpg')

data = [] # using an array is more convenient for tabulate.
j=1

for i in path:
    img = cv2.imread(i)
    #cv2.imshow(img,1)
    cv2.waitKey(0)
    cv2.destroyAllWindows()
    avgR = np.mean(img[:,:,2])/100
    avgG = np.mean(img[:,:,1])/100
    avgB = np.mean(img[:,:,0])/100

    varR = np.std(img[:,:,2])/100
    varG = np.std(img[:,:,1])/100
    varB = np.std(img[:,:,0])/100

    skewR = np.mean(scipy.stats.skew(img[:,:,2]))/100
    skewG = np.mean(scipy.stats.skew(img[:,:,1]))/100
    skewB = np.mean(scipy.stats.skew(img[:,:,0]))/100
    
    data.append([j,i, avgR, avgG, avgB, varR, varG, varB, skewR, skewG, skewB])
    j+=1
for i in range(len(data)):
    print(data[i])
    
#print(tabulate(data, headers=['img_name','R', 'G', 'B','varR','varG','varB','skewR','skewG','skewB'], tablefmt='fancy_grid'))
# Out:
# [1, 'Clean_water\\1.jpg', 0.3381337777777778, 1.7412831111111111, 1.9507755555555557, 0.13501992237014324, 0.10583774932145949, 0.08626135134463445, 0.005063420909636861, 0.002228567496935488, 0.003264465473405539]
# [2, 'Clean_water\\11.jpg', 0.13162888888888888, 1.5452755555555555, 1.2761106666666668, 0.14802903637420783, 0.34956792323956826, 0.10911395560809095, 0.016027906831073118, 0.0029988270872873452, 0.0038208020796899928]
# [3, 'Clean_water\\12.jpg', 0.8146795555555556, 1.1514142222222221, 1.211220888888889, 0.5195553307972139, 0.3983116255981205, 0.4262437050526232, 0.004777458906187535, 0.005530807340524495, 0.005137726642256959]
# [4, 'Clean_water\\13.jpg', 0.01525511111111111, 0.8041466666666666, 1.1585137777777779, 0.03626644341979218, 0.3114240778531209, 0.2871118172210099, 0.027949564595638944, -0.0010027904981440682, -0.0024629645870214013]
# ...

# %%
import glob
import cv2
import scipy
import statistics
from scipy.stats import skew
import numpy as np
import os
from tabulate import tabulate

#images = os.listdir('http://localhost:8888/tree/Desktop/Water_sample_images/Black_water')
#num_images = len(images)

files="Mud_water"
path=glob.glob(files+'/*.png')

data = [] # using an array is more convenient for tabulate.
j=1

for i in path:
    img = cv2.imread(i)
    #cv2.imshow(img,1)
    cv2.waitKey(0)
    cv2.destroyAllWindows()
    avgR = np.mean(img[:,:,2])/100
    avgG = np.mean(img[:,:,1])/100
    avgB = np.mean(img[:,:,0])/100

    varR = np.std(img[:,:,2])/100
    varG = np.std(img[:,:,1])/100
    varB = np.std(img[:,:,0])/100

    skewR = np.mean(scipy.stats.skew(img[:,:,2]))/100
    skewG = np.mean(scipy.stats.skew(img[:,:,1]))/100
    skewB = np.mean(scipy.stats.skew(img[:,:,0]))/100
    
    data.append([j,i, avgR, avgG, avgB, varR, varG, varB, skewR, skewG, skewB])
    j+=1
for i in range(len(data)):
    print(data[i])
    
#print(tabulate(data, headers=['img_name','R', 'G', 'B','varR','varG','varB','skewR','skewG','skewB'], tablefmt='fancy_grid'))
# Out:
# [1, 'Mud_water\\eenshot (198).png', 1.494104, 1.3205986666666667, 1.1066817777777778, 0.17049791613454462, 0.1777807433591539, 0.17534487433865725, 0.0011203701826218934, 0.0021088985580503426, 0.0026851722759928275]
# [2, 'Mud_water\\S.png', 0.8913524444444444, 1.1168755555555556, 1.1500324444444445, 0.09767696080346924, 0.09715192033455314, 0.10916907912154848, -0.005368001884561052, -0.006820345473680214, -0.00517689627560739]
# [3, 'Mud_water\\Sceenshot (204).png', 1.473551111111111, 1.166761777777778, 0.8458071111111112, 0.05744425944522113, 0.07238301308667781, 0.15562171268991742, 0.0011728288632086516, 0.001108173557674219, -0.0006450107431157253]
# [4, 'Mud_water\\Screenhot (201).png', 2.206347111111111, 2.068251111111111, 1.9925795555555554, 0.2688802186073215, 0.28282871779555296, 0.34264345463505774, -0.01711255295309882, -0.014420620505423191, -0.013007111983323527]
# ...

# %%
import glob
import cv2
import scipy
import statistics
from scipy.stats import skew
import numpy as np
import os
from tabulate import tabulate

#images = os.listdir('http://localhost:8888/tree/Desktop/Water_sample_images/Black_water')
#num_images = len(images)

files="Mud_water"
path=glob.glob(files+'/*.jpg')

data = [] # using an array is more convenient for tabulate.
j=1

for i in path:
    img = cv2.imread(i)
    #cv2.imshow(img,1)
    cv2.waitKey(0)
    cv2.destroyAllWindows()
    avgR = np.mean(img[:,:,2])/100
    avgG = np.mean(img[:,:,1])/100
    avgB = np.mean(img[:,:,0])/100

    varR = np.std(img[:,:,2])/100
    varG = np.std(img[:,:,1])/100
    varB = np.std(img[:,:,0])/100

    skewR = np.mean(scipy.stats.skew(img[:,:,2]))/100
    skewG = np.mean(scipy.stats.skew(img[:,:,1]))/100
    skewB = np.mean(scipy.stats.skew(img[:,:,0]))/100
    
    data.append([j,i, avgR, avgG, avgB, varR, varG, varB, skewR, skewG, skewB])
    j+=1
for i in range(len(data)):
    print(data[i])
    
#print(tabulate(data, headers=['img_name','R', 'G', 'B','varR','varG','varB','skewR','skewG','skewB'], tablefmt='fancy_grid'))
# Out:
# [1, 'Mud_water\\IMG-3515.jpg', 1.3937204444444444, 1.5430231111111112, 1.3679551111111112, 0.5323894423193757, 0.5313640128316399, 0.6617398083725865, 0.002154034705981666, 0.0017310074496952974, 0.0023157354815301753]
# [2, 'Mud_water\\OIP.jpg', 1.7238866666666666, 1.5933959999999998, 1.520775111111111, 0.32899895379772864, 0.3028874680390576, 0.296661609100127, -0.02001682322666879, -0.017982764961179155, -0.013876200308637033]
# [3, 'Mud_water\\R.jpg', 1.5321982222222224, 1.375340888888889, 1.1874639999999999, 0.5339883842235974, 0.557686940670808, 0.6281029036653858, -0.0074576408225344205, -0.0019664994232568237, 0.0007964078209201566]
# [4, 'Mud_water\\th (1).jpg', 1.6108733333333334, 1.3669973333333334, 1.194307111111111, 0.20079255619226086, 0.21209536008754803, 0.22711231659562656, 0.004363323371686761, 0.014055906093534338, 0.011498086950285522]
# ...

# %%
import glob
import cv2
import scipy
import statistics
from scipy.stats import skew
import numpy as np
import os
from tabulate import tabulate

#images = os.listdir('http://localhost:8888/tree/Desktop/Water_sample_images/Black_water')
#num_images = len(images)

files="Polluted_water"
path=glob.glob(files+'/*.jpg')

data = [] # using an array is more convenient for tabulate.
j=1

for i in path:
    img = cv2.imread(i)
    #cv2.imshow(img,1)
    cv2.waitKey(0)
    cv2.destroyAllWindows()
    avgR = np.mean(img[:,:,2])/100
    avgG = np.mean(img[:,:,1])/100
    avgB = np.mean(img[:,:,0])/100

    varR = np.std(img[:,:,2])/100
    varG = np.std(img[:,:,1])/100
    varB = np.std(img[:,:,0])/100

    skewR = np.mean(scipy.stats.skew(img[:,:,2]))/100
    skewG = np.mean(scipy.stats.skew(img[:,:,1]))/100
    skewB = np.mean(scipy.stats.skew(img[:,:,0]))/100
    
    data.append([j,i, avgR, avgG, avgB, varR, varG, varB, skewR, skewG, skewB])
    j+=1
for i in range(len(data)):
    print(data[i])
    
#print(tabulate(data, headers=['img_name','R', 'G', 'B','varR','varG','varB','skewR','skewG','skewB'], tablefmt='fancy_grid'))
# Out:
# [1, 'Polluted_water\\dark-water_MXWFXYOQYK.jpg', 0.8038755555555555, 0.8037657777777778, 0.8038755555555555, 0.4885258665529984, 0.48847308697154046, 0.4885258665529984, 0.004846898739560926, 0.004850920539802782, 0.004846898739560926]
# [2, 'Polluted_water\\images (1)(1).jpg', 1.291592, 1.3341404444444445, 1.2673533333333333, 0.24771596409866956, 0.2610308177800345, 0.41420870160933226, 0.002683348593844995, 0.002686522880404441, 0.0015672018886181424]
# [3, 'Polluted_water\\images (1)(2).jpg', 1.2740377777777778, 1.2755564444444445, 1.190852, 0.3274799174768085, 0.3164788589264029, 0.32593875138061684, 0.006977864433538724, 0.005937555553030266, 0.002131085886002167]
# [4, 'Polluted_water\\images (1).jpg', 1.377511111111111, 1.5038764444444446, 1.3395, 0.3031620631662376, 0.30443262319823416, 0.4079847314681164, 5.743495739423992e-05, -0.00017866222420777429, -0.0010043320116670765]
# ...

# %%
import glob
import cv2
import scipy
import statistics
from scipy.stats import skew
import numpy as np
import os
from tabulate import tabulate

#images = os.listdir('http://localhost:8888/tree/Desktop/Water_sample_images/Black_water')
#num_images = len(images)

files="Algae_water"
path=glob.glob(files+'/*.jpg')

data = [] # using an array is more convenient for tabulate.
j=1

for i in path:
    img = cv2.imread(i)
    #cv2.imshow(img,1)
    cv2.waitKey(0)
    cv2.destroyAllWindows()
    avgR = np.mean(img[:,:,2])/100
    avgG = np.mean(img[:,:,1])/100
    avgB = np.mean(img[:,:,0])/100

    varR = np.std(img[:,:,2])/100
    varG = np.std(img[:,:,1])/100
    varB = np.std(img[:,:,0])/100

    skewR = np.mean(scipy.stats.skew(img[:,:,2]))/100
    skewG = np.mean(scipy.stats.skew(img[:,:,1]))/100
    skewB = np.mean(scipy.stats.skew(img[:,:,0]))/100
    
    data.append([j,i, avgR, avgG, avgB, varR, varG, varB, skewR, skewG, skewB])
    j+=1
for i in range(len(data)):
    print(data[i])
    
#print(tabulate(data, headers=['img_name','R', 'G', 'B','varR','varG','varB','skewR','skewG','skewB'], tablefmt='fancy_grid'))
# Out:
# [1, 'Algae_water\\IMG-2937.jpg', 0.9266613333333333, 0.9606008888888888, 0.37489155555555553, 0.5094586843726061, 0.5100884662261906, 0.2179701544702909, -0.005212483232761807, -0.005239083509007448, -0.002691639225907672]
# [2, 'Algae_water\\IMG-2940.jpg', 1.3098133333333335, 1.7078617777777776, 0.8038444444444444, 0.24483382264530185, 0.23851673410931326, 0.29845357394822586, -0.004824280813724063, -0.011195055820394232, 0.0007928206938761771]
# [3, 'Algae_water\\IMG-2942.jpg', 0.9581146666666666, 1.6798226666666667, 0.8348871111111111, 0.46831970201562095, 0.3232571038965046, 0.694867188373664, -0.001740270441433247, -0.006205107591063289, -0.0014033233236362506]
# [4, 'Algae_water\\IMG-2944.jpg', 1.3559986666666666, 1.787833777777778, 0.981024, 0.3697270140077827, 0.4637903462331463, 0.44849533167593963, -0.0028283000755087795, -0.004646263530969473, 0.000907137271922795]
# ...

# %%
pip install keras
# Out:
# ...
#      ---------------------------------------- 1.7/1.7 MB 5.3 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip available: 22.2.2 -> 22.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pip install tensorflow
# Out:
# ...
#      ---------------------------------------- 455.9/455.9 MB ? eta 0:00:00
# ...
#      -------------------------------------- 42.6/42.6 kB 344.1 kB/s eta 0:00:00
# ...
#      -------------------------------------- 438.7/438.7 kB 2.7 MB/s eta 0:00:00
#
# ...
# [notice] A new release of pip available: 22.2.2 -> 22.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ...
#      ---------------------------------------- 14.2/14.2 MB 5.3 MB/s eta 0:00:00
# ...
#      -------------------------------------- 57.5/57.5 kB 749.7 kB/s eta 0:00:00
# ...
#      -------------------------------------- 65.5/65.5 kB 442.0 kB/s eta 0:00:00
# ...
#      ---------------------------------------- 1.5/1.5 MB 4.5 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 5.9/5.9 MB 6.1 MB/s eta 0:00:00
# ...
#      -------------------------------------- 124.6/124.6 kB 1.5 MB/s eta 0:00:00
# ...
#      -------------------------------------- 781.3/781.3 kB 4.1 MB/s eta 0:00:00
# ...

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
from sklearn import metrics 
import warnings
warnings.filterwarnings('ignore')

# %%
#Loading data into dataframe

data = pd.read_csv("Dataset_updated.csv")
data.head()
# Out:
#                   Image_Name  First_order_moment  Unnamed: 2  Unnamed: 3  \
# 0   'Clean_water\\1 (2).png'              0.0185      1.2714      1.3673
# 1   'Clean_water\\1 (3).png'              0.0088      0.7979      1.2789
# 2   'Clean_water\\1 (4).png'              0.3818      1.7833      1.9392
# 3   'Clean_water\\1 (5).png'              1.1441      1.6544      1.9084
# 4   'Clean_water\\1 (7).png'              1.2278      1.9341      1.5803
#
#    Second_order_moment  Unnamed: 5  Unnamed: 6  Third_order_moment  \
# 0               0.0255      0.1517      0.1101              0.0176
# 1               0.0116      0.0633      0.0586              0.0152
# 2               0.6184      0.4045      0.2140              0.0134
# 3               0.6948      0.5680      0.5013             -0.0008
# 4               0.4394      0.1917      0.2490             -0.0016
#
#    Unnamed: 8  Unnamed: 9  class
# 0     -0.0026     -0.0002  Clean
# 1     -0.0010     -0.0084  Clean
# ...

# %%
# Splitting the dataset into dependant and independant fetature

X = data. iloc[:, [1,2,3,4,5,6,7,8,9]]
y = data["class"]

# %%
print(X)
print(y)
# Out:
#       First_order_moment  Unnamed: 2  Unnamed: 3  Second_order_moment  \
# 0                 0.0185      1.2714      1.3673               0.0255
# 1                 0.0088      0.7979      1.2789               0.0116
# 2                 0.3818      1.7833      1.9392               0.6184
# 3                 1.1441      1.6544      1.9084               0.6948
# 4                 1.2278      1.9341      1.5803               0.4394
# ...                  ...         ...         ...                  ...
# 2129              1.1711      1.5082      0.9807               0.2531
# 2130              1.1522      1.6500      0.6982               0.3255
# 2131              0.7909      1.4087      0.6972               0.3263
# 2132              1.0020      1.3204      0.8379               0.1548
# 2133              0.8487      1.6912      0.6624               0.1278
#
#       Unnamed: 5  Unnamed: 6  Third_order_moment  Unnamed: 8  Unnamed: 9
# ...

# %%
#Splitting the data into Training and Testing
x_train, x_test, y_train, y_test = train_test_split(X, y, train_size=0.7, random_state=42)

# %%
from sklearn.model_selection import train_test_split

from sklearn.metrics import confusion_matrix,classification_report,accuracy_score

from sklearn.tree import DecisionTreeClassifier

# %%
#Decision Tree
dt_model = DecisionTreeClassifier()
dt_model.fit(x_train,y_train)

dt_predictions = dt_model.predict(x_test)
accuracy_score(y_test,dt_predictions)
# Out:
# 0.8673946957878315

# %%
cm=confusion_matrix(y_test,dt_predictions)
print(cm)
# Out:
# [[144   0   2  11]
#  [  4 149   8   6]
#  [  0   2 128  20]
#  [ 10   5  17 135]]

# %%
from mlxtend.plotting import plot_confusion_matrix
 
fig, ax = plot_confusion_matrix(conf_mat=cm, figsize=(6, 6), cmap=plt.cm.Greens)
plt.xlabel('Predictions', fontsize=18)
plt.ylabel('Actuals', fontsize=18)
plt.title('Confusion Matrix', fontsize=18)
plt.show()

# %%
pip install mlxtend
# Out:
# ...
#   Using cached mlxtend-0.21.0-py2.py3-none-any.whl (1.3 MB)
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip available: 22.2.2 -> 22.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from sklearn.ensemble import RandomForestClassifier
rfc = RandomForestClassifier()
rfc.fit(x_train, y_train)

rfc_predictions = rfc.predict(x_test)
accuracy_score(y_test, rfc_predictions)
# Out:
# 0.9079563182527302

# %%
print(confusion_matrix(y_test,rfc_predictions))
# Out:
# [[147   1   3   6]
#  [  1 156   5   5]
#  [  0   1 135  14]
#  [  7   3  13 144]]

# %%
from sklearn.linear_model import LogisticRegression

log_model = LogisticRegression()
log_model.fit(x_train,y_train)

log_predictions = log_model.predict(x_test)
accuracy_score(y_test,log_predictions)
# Out:
# 0.8954758190327613

# %%
print(confusion_matrix(y_test,log_predictions))
# Out:
# [[149   0   1   7]
#  [  1 151   8   7]
#  [  0   0 134  16]
#  [ 10   1  16 140]]

# %%
from sklearn.neural_network import MLPClassifier
clf = MLPClassifier()
clf.fit(X, y)
# Out:
# MLPClassifier()

# %%
pred=clf.predict(x_test)
accuracy_score(y_test,pred)
# Out:
# 0.9375975039001561

# %%
cm=confusion_matrix(y_test,pred)
print(cm)
# Out:
# [[151   0   0   6]
#  [  1 159   2   5]
#  [  0   0 139  11]
#  [  5   0  10 152]]

# %%
from mlxtend.plotting import plot_confusion_matrix
 
fig, ax = plot_confusion_matrix(conf_mat=cm, figsize=(6, 6), cmap=plt.cm.Greens)
plt.xlabel('Predictions', fontsize=18)
plt.ylabel('Actuals', fontsize=18)
plt.title('Confusion Matrix', fontsize=18)
plt.show()

# %%
import os
import glob
import cv2
import numpy as np
import pandas as pd
from PIL import Image 
from pathlib import Path
from keras.models import Sequential,Model,load_model
from keras.applications.vgg16 import VGG16,preprocess_input
from keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.utils import load_img,img_to_array
from keras.layers import Conv2D, MaxPooling2D, Dense, Dropout, Input,Flatten,Activation
from keras.optimizers import Adam, SGD, RMSprop
from keras.callbacks import Callback, EarlyStopping
from keras.utils import to_categorical
from sklearn.metrics import confusion_matrix
from keras import backend as K
import tensorflow as tf
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
print(os.listdir("Water_samples/"))
# Out:
# ['Test', 'Test.zip', 'Train', 'Train.zip', 'val']

# %%
data_dir=Path("Water_samples/")
train_dir=data_dir/'train'
test_dir=data_dir/'test'
val_dir=data_dir/'val'

# %%
def load_train():
    polluted_water_dir = train_dir/'Polluted'
    clean_water_dir = train_dir/'Clean'
    mud_water_dir = train_dir/'Mud'
    algae_water_dir = train_dir/'Algae'
    
    polluted_water=polluted_water_dir.glob('*.jpg')
    clean_water=clean_water_dir.glob('*.jpg')
    mud_water=mud_water_dir.glob('*.jpg')
    algae_water=algae_water_dir.glob('*.jpg')
    
    polluted_water1=polluted_water_dir.glob('*.png')
    clean_water1=clean_water_dir.glob('*.png')
    mud_water1=mud_water_dir.glob('*.png')
    algae_water1=algae_water_dir.glob('*.png')
    train_data=[]
    train_label=[]
    for img in polluted_water:
        train_data.append(img)
        train_label.append("Polluted_water")
    for img in clean_water:
        train_data.append(img)
        train_label.append("Clean_water")
    for img in mud_water:
        train_data.append(img)
        train_label.append("Mud_water")
    for img in algae_water:
        train_data.append(img)
        train_label.append("Algae_water")
    
    for img in polluted_water1:
        train_data.append(img)
        train_label.append("Polluted_water")
    for img in clean_water1:
        train_data.append(img)
        train_label.append("Clean_water")
    for img in mud_water1:
        train_data.append(img)
        train_label.append("Mud_water")
    for img in algae_water1:
        train_data.append(img)
        train_label.append("Algae_water")
    df=pd.DataFrame(train_data)
    df.columns=['images']
    df['labels']=train_label
    df=df.sample(frac=1).reset_index(drop=True)
    return df

# %%
train_data=load_train()
train_data.shape
# Out:
# (1600, 2)

# %%
plt.bar(train_data['labels'].value_counts().index,train_data['labels'].value_counts().values)
plt.show()

# %%
def plot(image_batch,label_batch):
    plt.figure(figsize=(10,5))
    for i in range(10):
        ac=plt.subplot(2,5,i+1)
        img=cv2.imread(str(image_batch[i]))
        img=cv2.resize(img,(150,150))
        plt.imshow(img)
        plt.title(label_batch[i])
        plt.axis("off")

# %%
plot(train_data['images'],train_data['labels'])

# %%
def prepare_and_load(isval=True):
    
    if(isval==True):
        polluted_water_dir = val_dir/'Polluted'
        clean_water_dir = val_dir/'Clean'
        mud_water_dir = val_dir/'Mud'
        algae_water_dir = val_dir/'Algae'
    else:
        polluted_water_dir = test_dir/'Polluted'
        clean_water_dir = test_dir/'Clean'
        mud_water_dir = test_dir/'Mud'
        algae_water_dir = test_dir/'Algae'
    
    polluted_water=polluted_water_dir.glob('*.jpg')
    clean_water=clean_water_dir.glob('*.jpg')
    mud_water=mud_water_dir.glob('*.jpg')
    algae_water=algae_water_dir.glob('*.jpg')
    
    polluted_water1=polluted_water_dir.glob('*.png')
    clean_water1=clean_water_dir.glob('*.png')
    mud_water1=mud_water_dir.glob('*.png')
    algae_water1=algae_water_dir.glob('*.png')
    data,labels=([] for x in range(2))
    
    def prepare (case):
        for img in case:
            img = cv2.imread(str(img))
            img = cv2.resize(img, (150,150))
            if img.shape [2] ==1:
                img = np.dstack([img, img, img])
            img = cv2.cvtColor (img, cv2.COLOR_BGR2RGB)
            img = img.astype (np.float32)/255.
            if case==polluted_water:
                label = to_categorical (0, num_classes=4)
            elif case==clean_water:
                label = to_categorical(1, num_classes=4)
            elif case==mud_water:
                label = to_categorical(2, num_classes=4)
            else:
                label = to_categorical(3, num_classes=4)
            data.append(img)
            labels.append(label)
        return data, labels
    prepare (polluted_water)
    prepare (clean_water)
    prepare (algae_water)
    d,l=prepare (mud_water)
    d=np.array(d)
    l=np.array(l)
    return d, l

# %%
val_data,val_labels=prepare_and_load(isval=True)
test_data,test_labels=prepare_and_load(isval=False)
print('Number of test images-->',len(test_data))
print('Number of validation images-->',len(val_data))
# Out:
# Number of test images--> 350
# Number of validation images--> 12

# %%
def data_gen(data, batch_size):
    # Get total number of samples in the data
    n = len (data)
    steps = n//batch_size
    # Define two numpy arrays for containing batch data and Labels
    batch_data = np.zeros((batch_size, 150, 150, 3), dtype=np.float32)
    batch_labels=np.zeros((batch_size,4), dtype=np.float32)
    # Get a numpy array of all the indices of the input data
    indices = np.arange(n)
    tf.reshape(batch_data,[-1])
    # Initialize a counter
    i=0
    while True:
        np.random.shuffle (indices)
        # Get the next batch
        count = 0
        next_batch = indices [ (i* batch_size): (i+1)*batch_size]
        for j, idx in enumerate (next_batch):
            img_name=data.iloc[idx]['images']
            label =data.iloc[idx]['labels']
            if label=='Polluted_water':
                label=0
            elif label=='Clean_water':
                label=1
            elif label=='Mud_water':
                label=2
            elif label=='Algae_water':
                label=3
            # one hot encoding
            encoded_label= to_categorical (label, num_classes=4)
            
            # read the image and resize
            img = cv2.imread(str(img_name))
            img = cv2.resize (img, (150, 150))
            # check if it's grayscale
            if img.shape [2]==1:
                img = np.dstack([img, img, img])
            # cv2 reads in BGR mode by default
            orig_img=cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
            # normalize the image pixels
            orig_img=img.astype(np.float32)/255.
            batch_data[count] = orig_img
            batch_labels[count] = encoded_label
            count+=1
            if count==batch_size-1:
                break
        i+=1
        yield batch_data, batch_labels
        if i>=steps:
            i=0

# %%
model = Sequential() 
model.add(Conv2D(32, (3, 3), input_shape=(150, 150,3))) 
model.add(Activation('relu')) 
model.add(MaxPooling2D(pool_size=(2, 2))) 
model.add(Conv2D(32, (3, 3))) 
model.add(Activation('relu')) 
model.add(MaxPooling2D(pool_size=(2, 2))) 
model.add(Conv2D(64, (3, 3))) 
model.add(Activation ('relu')) 
model.add(MaxPooling2D(pool_size=(2, 2))) 
model.add(Flatten()) # this converts our 3D feature maps to 1D feature vectors 
model.add(Dense(64)) 
model.add(Activation( 'relu')) 
model.add(Dense(4)) 
model.add(Activation('softmax'))

# %%
batch_size=12
nb_epochs = 10

train_data_gen=data_gen(data=train_data,batch_size=batch_size)

nb_train_steps=train_data.shape[0]//batch_size

print("Number of training steps : {} and {}".format(nb_train_steps,len(val_data)))
# Out:
# Number of training steps : 133 and 12

# %%
model.compile(loss='binary_crossentropy',optimizer='rmsprop',metrics=['accuracy'])

history=model.fit_generator(train_data_gen,epochs=nb_epochs,steps_per_epoch=nb_train_steps,validation_data=(val_data,val_labels))
# Out:
# Epoch 1/10
# C:\Users\admin\AppData\Local\Temp\ipykernel_980\563801993.py:3: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   history=model.fit_generator(train_data_gen,epochs=nb_epochs,steps_per_epoch=nb_train_steps,validation_data=(val_data,val_labels))
# 133/133 [==============================] - 43s 311ms/step - loss: 0.1577 - accuracy: 0.8697 - val_loss: 1.1516 - val_accuracy: 0.5000
# Epoch 2/10
# 133/133 [==============================] - 42s 313ms/step - loss: 0.1267 - accuracy: 0.8985 - val_loss: 2.6701 - val_accuracy: 0.4167
# Epoch 3/10
# 133/133 [==============================] - 41s 311ms/step - loss: 0.1131 - accuracy: 0.8891 - val_loss: 1.0917 - val_accuracy: 0.5833
# Epoch 4/10
# 133/133 [==============================] - 40s 301ms/step - loss: 0.1257 - accuracy: 0.8759 - val_loss: 1.5238 - val_accuracy: 0.5000
# Epoch 5/10
# ...

# %%
def vgg16_model( num_classes = None):
    model = VGG16(weights = 'imagenet', include_top = True, input_shape=(224,224,3))
    x = Dense(1024, activation = 'relu')(model.layers[-4].output)
    x=Dropout(0.7)(x)
    x = Dense(512, activation = 'relu')(x)
    x=Dropout(0.5)(x)
    x = Dense(4, activation = 'softmax')(x)
    model = Model(model.input, x)
    #tf.reshape(x,[-1])
    return model

# %%
vgg_conv = vgg16_model(4)
for layer in vgg_conv.layers[:-10]:
    layer.trainable = False

# %%
opt = Adam(lr=0.0001, decay = 1e-5)
vgg_conv.compile(loss='binary_crossentropy', metrics=['accuracy'],optimizer=opt)

# %%
history = vgg_conv.fit_generator(train_data_gen, epochs=nb_epochs, steps_per_epoch = nb_train_steps, validation_data = (val_data,val_labels))
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_10236\859392484.py:1: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   history = vgg_conv.fit_generator(train_data_gen, epochs=nb_epochs, steps_per_epoch = nb_train_steps, validation_data = (val_data,val_labels))
# Epoch 1/3
# ---------------------------------------------------------------------------
# InvalidArgumentError                      Traceback (most recent call last)
# Input In [32], in <cell line: 1>()
# ----> 1 history = vgg_conv.fit_generator(train_data_gen, epochs=nb_epochs, steps_per_epoch = nb_train_steps, validation_data = (val_data,val_labels))
#
# ...

# %%
loss, acc = vgg_conv.evaluate(test_data, test_labels, batch_size=16)
print('loss and accuracy', loss, '&', acc)

# %%
pred = model.predict(test_data, batch_size=16)
pred = np.argmax(pred, axis = 1)
labels = np.argmax(test_labels, axis = -1)
from sklearn.metrics import classification_report
print(classification_report(labels, pred))
# Out:
# 22/22 [==============================] - 3s 99ms/step
#               precision    recall  f1-score   support
#
#            0       0.65      0.64      0.65        98
#            1       0.01      0.02      0.01        52
#            2       0.36      0.12      0.18       100
#            3       0.74      0.84      0.79       100
#
#     accuracy                           0.46       350
#    macro avg       0.44      0.41      0.41       350
# weighted avg       0.50      0.46      0.46       350
